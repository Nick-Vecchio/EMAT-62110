# %% [markdown]
#  Systems Check
# # Nick Vecchio
# ## 8/20/2024

# %%
x

# %%
3

# %%
my_list = [2,3,4,5]
my_list
# Out:
# [2, 3, 4, 5]

# %%
my_list[0]
# Out:
# 2

# %%
my_name = 'Nick'

# %%
def display_name(x):
    print(x)

# %%
display_name(my_name)
# Out:
# Nick

# %% [markdown]
# # This is heading 1
# ## This is heading 2
# ## __Beagle Names__
# * _Lily_
# * Daisy
# * Rosie
# * Poppy
# * Violet
# * Rosalina
#
# ![image.png](attachment:983fa546-926e-4f8f-bc04-2c1b90b6e716.png)
#
# ### I hope to learn a bit more about Python and data visualization in general.
